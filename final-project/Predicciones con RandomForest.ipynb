# %% [markdown]
# # Predicciones con RandomForest

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import pandas.io

import matplotlib.pyplot as plt

import librosa.display
import librosa

from glob import glob

import ffmpeg

import os

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import linear_model
from sklearn.metrics import accuracy_score
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.neighbors import KNeighborsClassifier

from scipy import interp

from itertools import cycle

import seaborn as sns

import pickle

# %%
def readCsvToDataFrame(path):
    theDataFrame= pandas.read_csv(path)
    return theDataFrame

data = readCsvToDataFrame('data.csv')

# %%
y = pd.get_dummies(data=data.momento_aux)
X = data.loc[:, data.columns != 'momento_aux']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)

# %%
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-9cba6f31235c> in <module>
# ----> 1 model.fit(X_train, y_train)
#       2 model.score(X_test, y_test)
#
# NameError: name 'model' is not defined

# %%
filename = 'finalized_model.sav'

# %%
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_test, y_test)
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-abdc017eda24> in <module>
#       1 loaded_model = pickle.load(open(filename, 'rb'))
# ----> 2 result = loaded_model.score(X_test, y_test)
#       3 print(result)
#
# NameError: name 'X_test' is not defined

# %%
prueba1 = pd.read_csv('data_prueba.csv')
prueba1
# Out:
#          mfcc         scem       scom         srom         sbwm       tempo  \
# 0   -5.617919  4822.729698  17.012424  8490.626926  2922.254333  129.199219
# 1   -2.063152   452.804643  17.915530   811.142272   535.833205  129.199219
# 2  -25.202837  1554.105964  27.932041  3095.535342  1372.209905  151.999081
# 3    4.669409   669.271532  16.381503   727.032881  1716.868434  117.453835
# 4   -1.508489  1186.695657  18.275804  2155.318754  2039.238339  107.666016
# 5   -3.035361  2508.270707  25.810619  4608.405235  2341.296911  117.453835
# 6  -12.056254  2727.620419  18.929312  5360.468591  2403.742428  123.046875
# 7  -26.344146  1630.421174  26.129081  3218.989043  1388.219723  117.453835
# 8   -2.924622  2876.000263  19.457674  6356.741453  2784.884735  117.453835
# 9  -10.544885  3399.908268  22.133242  7362.332047  2706.150931  117.453835
# 10  -8.384757  5980.407268  15.264916  9110.993012  2828.106212  129.199219
# 11  -5.174857  1264.247949  21.390439  2744.634061  1345.232231  129.199219
# 12   8.228639   701.830548  20.117285   815.538843  1634.695428  123.046875
# 13  -9.622233  4928.474676  16.521271  8882.296406  3148.989801  129.199219
# 14 -27.696898  4670.668320  20.406719  6957.697680  2139.072891  129.199219
# 15 -19.467162  3332.343606  16.664355  6556.085956  2603.296770  129.199219
# 16 -22.715169  1351.671275  28.182421  1883.980410   948.230813  112.347147
# 17 -10.040551  2717.740563  18.464756  5670.376849  2616.867447  123.046875
# 18 -21.459621  3207.246760  15.772001  7659.050593  3325.945286  117.453835
#
#         rmse             momento
# 0   0.056099               Grifo
# 1   0.084744  Aire_acondicionado
# 2   0.035863                Cena
# 3   0.143639            Secadora
# 4   0.149006            Secadora
# 5   0.086121          Afeitadora
# 6   0.131954        Secador_pelo
# 7   0.032983                Cena
# 8   0.074781           Licuadora
# 9   0.156983              Alarma
# 10  0.027165               Ducha
# 11  0.053251          Microondas
# 12  0.213590            Lavadora
# 13  0.130054               Ducha
# 14  0.019722            Telefono
# 15  0.004539              Tecleo
# 16  0.108515              Timbre
# 17  0.071655          Aspiradora
# 18  0.000652            Silencio

# %%
X_new = prueba1.loc[:, prueba1.columns != 'momento']
y_new = loaded_model.predict(X_new)
y_new2 = loaded_model.predict_proba(X_new)

for i in range(len(X_new)):
    predicted_list = y_new[i].tolist()
    if 1 in predicted_list:
        predicted_class = list(y)[y_new[i].tolist().index(1)]
        predicted_probability = y_new2[i].tolist()[y_new[i].tolist().index(1)]
        print('Para este audio el valor predicho es {} y la probabilidad de haber acertado es del {:.2f}%.'.format(predicted_class, predicted_probability*100))
    else:
        print('El sonido analizado no se encuentra entre los sonidos más comunes de una casa.')
# Out:
# Para este audio el valor predicho es Grifo y la probabilidad de haber acertado es del 98.33%.
# Para este audio el valor predicho es Aire_acondicionado y la probabilidad de haber acertado es del 66.67%.
# Para este audio el valor predicho es Cena y la probabilidad de haber acertado es del 100.00%.
# Para este audio el valor predicho es Secadora y la probabilidad de haber acertado es del 91.67%.
# Para este audio el valor predicho es Secadora y la probabilidad de haber acertado es del 85.00%.
# Para este audio el valor predicho es Afeitadora y la probabilidad de haber acertado es del 73.33%.
# Para este audio el valor predicho es Secador_pelo y la probabilidad de haber acertado es del 68.33%.
# Para este audio el valor predicho es Cena y la probabilidad de haber acertado es del 100.00%.
# Para este audio el valor predicho es Licuadora y la probabilidad de haber acertado es del 65.00%.
# Para este audio el valor predicho es Alarma y la probabilidad de haber acertado es del 91.67%.
# Para este audio el valor predicho es Ducha y la probabilidad de haber acertado es del 73.33%.
# Para este audio el valor predicho es Microondas y la probabilidad de haber acertado es del 100.00%.
# Para este audio el valor predicho es Lavadora y la probabilidad de haber acertado es del 88.33%.
# El sonido analizado no se encuentra entre los sonidos más comunes de una casa.
# Para este audio el valor predicho es Telefono y la probabilidad de haber acertado es del 100.00%.
# Para este audio el valor predicho es Tecleo y la probabilidad de haber acertado es del 88.33%.
# Para este audio el valor predicho es Timbre y la probabilidad de haber acertado es del 100.00%.
# Para este audio el valor predicho es Aspiradora y la probabilidad de haber acertado es del 61.67%.
# Para este audio el valor predicho es Silencio y la probabilidad de haber acertado es del 81.67%.
